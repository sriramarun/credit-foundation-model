# %% [markdown]
# # 01 · Data & Baseline

# %% [markdown]
# Load the synthetic Dutch RMBS panel (`Algoritmica/green-lion-2024-2025`), build temporal + loan-stratified splits, and train an XGBoost baseline for `default_6m`.

# %%
# TODO
