# %% [markdown]
# # 02 · Tokenization

# %% [markdown]
# Demonstrate the key-value-time tokenizer: build vocab, encode a loan panel, inspect key/value/temporal decomposition and sequence-length stats.

# %%
# TODO
