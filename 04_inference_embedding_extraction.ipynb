# %% [markdown]
# # 04 · Inference & Embedding Extraction

# %% [markdown]
# Load a checkpoint and extract embeddings at prediction points (`src.decoder_inference`) with last-token / mean / event-anchor / window pooling. Write embedding parquet.
#
# *Phase 5. Mirrors NVIDIA `04_inference_embedding_extraction`.*

# %%
# TODO: implement this phase
