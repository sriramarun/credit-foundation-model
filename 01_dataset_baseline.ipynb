# %% [markdown]
# # 01 · Dataset & Baseline

# %% [markdown]
# Load credit datasets, build the observation-date feature store, create **temporal** train/val/test splits, and train XGBoost/LightGBM/logistic baselines for default/delinquency.
#
# *Phase 1–2. Mirrors NVIDIA `01_dataset_baseline`.*

# %%
# TODO: implement this phase
