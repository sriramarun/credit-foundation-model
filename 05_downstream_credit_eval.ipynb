# %% [markdown]
# # 05 · Downstream Credit Evaluation

# %% [markdown]
# Train downstream models on raw / embeddings-only / raw+embeddings and compare lift, calibration, and stability by vintage. Populate the `Metrics` table and `reports/downstream_eval.md`.
#
# *Phase 5. Credit analogue of NVIDIA `05_xgboost_fraud_detection`.*

# %%
# TODO: implement this phase
