# %% [markdown]
# # 02 · Sequence Preprocessing & Tokenization

# %% [markdown]
# Build borrower→loan→observation event sequences and tokenize them with `src.tokenizer.CreditTabularTokenizer`. Emit train/val/test decoder corpora and the tokenizer QA report (OOV, rare-token, sequence-length).
#
# *Phase 3. Mirrors NVIDIA `02_seq_preproc_tokenization`.*

# %%
# TODO: implement this phase
